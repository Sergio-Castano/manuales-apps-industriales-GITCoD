# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import h5py
import numpy as np

h5_path = "/content/drive/MyDrive/Codigos_Fallos/Carpeta_Dataset/dataset_sync.h5"

X_vib, X_acoustic, X_current, y = [], [], [], []

with h5py.File(h5_path, "r") as f:
    for cond in f.keys():
        g = f[cond]
        try:
            # Vibración
            v1 = g["vibration"]["accel_1"]["signal_sync"][:].astype(np.float32)
            v2 = g["vibration"]["accel_2"]["signal_sync"][:].astype(np.float32)
            if len(v1) == 0 or len(v2) == 0:
                continue
            min_len_vib = min(len(v1), len(v2))
            vib = np.stack([v1[:min_len_vib], v2[:min_len_vib]], axis=0)

            # Acústico
            if "acoustic" in g:
                a = g["acoustic"]["signal_sync"][:].astype(np.float32)
                if len(a) == 0:
                    a = np.zeros(min_len_vib, dtype=np.float32)
            else:
                a = np.zeros(min_len_vib, dtype=np.float32)

            # Corriente
            if "current" in g["external"]:
                cur = g["external"]["current"]["signal_sync"][:].astype(np.float32)
                if len(cur) == 0:
                    cur = np.zeros(min_len_vib, dtype=np.float32)
            else:
                cur = np.zeros(min_len_vib, dtype=np.float32)

            # Ajustar longitud mínima
            min_len_group = min(min_len_vib, len(a), len(cur))
            vib = vib[:, :min_len_group]
            a   = a[:min_len_group]
            cur = cur[:min_len_group]

            # Guardar
            X_vib.append(vib)
            X_acoustic.append(a)
            X_current.append(cur)
            y.append(cond)

        except Exception as e:
            print(f"Saltando {cond} por error: {e}")

# Recorte global
min_len_all = min(
    min(x.shape[1] for x in X_vib),
    min(len(a) for a in X_acoustic),
    min(len(c) for c in X_current)
)

X_vib      = np.array([x[:, :min_len_all] for x in X_vib])
X_acoustic = np.array([a[:min_len_all] for a in X_acoustic])
X_current  = np.array([c[:min_len_all] for c in X_current])
y          = np.array(y)

print("Shapes después de recorte global:")
print("Vib:", X_vib.shape)
print("Acoustic:", X_acoustic.shape)
print("Current:", X_current.shape)
print("y:", y.shape)
# Out:
# Shapes después de recorte global:
# Vib: (45, 2, 1536000)
# Acoustic: (45, 1536000)
# Current: (45, 1536000)
# y: (45,)

# %%
# Mapping de clases
unique_labels = sorted(set(y))
label_map = {name: idx for idx, name in enumerate(unique_labels)}
y_idx = np.array([label_map[name] for name in y])

num_classes = len(unique_labels)
print("Número de clases:", num_classes)

# Expandir dimensiones
X_acoustic = X_acoustic[:, np.newaxis, :]   # (N,1,L)
X_current  = X_current[:, np.newaxis, :]    # (N,1,L)

# Concatenar vib (2) + ac (1) = (3,L) → entrada CNN
X_base = np.concatenate([X_vib, X_acoustic], axis=1)

# Normalización z-score
mean_base = X_base.mean(axis=(0,2), keepdims=True)
std_base  = X_base.std(axis=(0,2), keepdims=True) + 1e-8
X_base = (X_base - mean_base) / std_base

mean_cur = X_current.mean(axis=(0,2), keepdims=True)
std_cur  = X_current.std(axis=(0,2), keepdims=True) + 1e-8
X_current = (X_current - mean_cur) / std_cur

print("X_base:", X_base.shape, "X_current:", X_current.shape)
# Out:
# Número de clases: 45
# X_base: (45, 3, 1536000) X_current: (45, 1, 1536000)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class FuzzyLayerInput(nn.Module):
    def __init__(self, n_sets=3, out_dim=64):
        super(FuzzyLayerInput, self).__init__()
        self.n_sets = n_sets
        self.centers = nn.Parameter(torch.linspace(-1, 1, n_sets))
        self.sigmas  = nn.Parameter(torch.ones(n_sets) * 0.5)

        self.conv = nn.Sequential(
            nn.Conv1d(n_sets, 16, kernel_size=5, stride=2, padding=2),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(16)
        )
        self.fc = nn.Linear(16*16, out_dim)

    def membership(self, x, c, s):
        return torch.exp(-0.5 * ((x - c) / s) ** 2)

    def forward(self, x):
        """
        x: (B,1,L) → corriente normalizada
        """
        B, _, L = x.shape
        sets = []
        for j in range(self.n_sets):
            mu = self.membership(x.squeeze(1), self.centers[j], self.sigmas[j])  # (B,L)
            sets.append(mu.unsqueeze(1))
        fuzzy_out = torch.cat(sets, dim=1)      # (B,n_sets,L)
        feat = self.conv(fuzzy_out).flatten(1)  # (B,256)
        return self.fc(feat)                    # (B,out_dim)

# %%
class CNN_FuzzyCurrentInput(nn.Module):
    def __init__(self, num_classes):
        super(CNN_FuzzyCurrentInput, self).__init__()
        # CNN para vib + acoustic
        self.conv = nn.Sequential(
            nn.Conv1d(3, 16, kernel_size=7, stride=2, padding=3),
            nn.BatchNorm1d(16),
            nn.ReLU(),
            nn.Conv1d(16, 32, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(64)
        )
        # Fuzzy para corriente
        self.fuzzy_cur = FuzzyLayerInput(n_sets=3, out_dim=64)

        # Clasificador → concatena CNN feat (2048) + fuzzy_cur feat (64)
        self.fc = nn.Sequential(
            nn.Linear(32*64 + 64, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def forward(self, x_base, x_cur):
        feat_cnn = self.conv(x_base).flatten(1)    # (B,2048)
        feat_cur = self.fuzzy_cur(x_cur)           # (B,64)
        feat_all = torch.cat([feat_cnn, feat_cur], dim=1)
        return self.fc(feat_all)

# %%
from torch.utils.data import Dataset, DataLoader, random_split

class MotorDatasetCurrentInput(Dataset):
    def __init__(self, X_base, X_current, y, window_size=2048, step=2048):
        self.X_base = X_base
        self.X_current = X_current
        self.y = y
        self.window_size = window_size
        self.step = step
        self.indices = []
        for i in range(len(X_base)):
            n = X_base[i].shape[1]
            for start in range(0, n - window_size + 1, step):
                end = start + window_size
                self.indices.append((i, start, end))

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        sample_idx, start, end = self.indices[idx]
        x_base = self.X_base[sample_idx][:, start:end]     # (3, win)
        x_cur  = self.X_current[sample_idx][:, start:end]  # (1, win)
        label  = self.y[sample_idx]
        return (
            torch.tensor(x_base, dtype=torch.float32),
            torch.tensor(x_cur, dtype=torch.float32),
            torch.tensor(label, dtype=torch.long),
        )

dataset = MotorDatasetCurrentInput(X_base, X_current, y_idx, window_size=2048, step=2048)

train_size = int(0.8 * len(dataset))
val_size   = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=32, shuffle=False)

print("Ventanas totales:", len(dataset))
print("Train:", len(train_dataset), "Val:", len(val_dataset))
# Out:
# Ventanas totales: 33750
# Train: 27000 Val: 6750

# %%
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CNN_FuzzyCurrentInput(num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

num_epochs = 200
patience = 15
best_val_acc = 0.0
epochs_no_improve = 0
best_model_path = "best_model_fuzzy_current_input.pth"

for epoch in range(num_epochs):
    model.train()
    train_loss, train_correct, total = 0, 0, 0
    for x_base, x_cur, y_batch in train_loader:
        x_base, x_cur, y_batch = x_base.to(device), x_cur.to(device), y_batch.to(device)

        optimizer.zero_grad()
        outputs = model(x_base, x_cur)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * x_base.size(0)
        preds = outputs.argmax(dim=1)
        train_correct += (preds == y_batch).sum().item()
        total += y_batch.size(0)

    train_acc = train_correct / total
    train_loss /= total

    model.eval()
    val_loss, val_correct, total_val = 0, 0, 0
    with torch.no_grad():
        for x_base, x_cur, y_batch in val_loader:
            x_base, x_cur, y_batch = x_base.to(device), x_cur.to(device), y_batch.to(device)
            outputs = model(x_base, x_cur)
            loss = criterion(outputs, y_batch)

            val_loss += loss.item() * x_base.size(0)
            preds = outputs.argmax(dim=1)
            val_correct += (preds == y_batch).sum().item()
            total_val += y_batch.size(0)

    val_acc = val_correct / total_val
    val_loss /= total_val

    print(f"Epoch [{epoch+1}/{num_epochs}] "
          f"Train Loss: {train_loss:.4f}, Acc: {train_acc:.4f} "
          f"Val Loss: {val_loss:.4f}, Acc: {val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        epochs_no_improve = 0
        torch.save(model.state_dict(), best_model_path)
        print(f"✅ Mejor modelo guardado en epoch {epoch+1} con val_acc={val_acc:.4f}")
    else:
        epochs_no_improve += 1

    if epochs_no_improve >= patience:
        print("⏹ Early stopping activado")
        break

print(f"Entrenamiento finalizado. Mejor val_acc={best_val_acc:.4f}, modelo en {best_model_path}")
# Out:
# Epoch [1/200] Train Loss: 1.4903, Acc: 0.4484 Val Loss: 0.5327, Acc: 0.8295
# ✅ Mejor modelo guardado en epoch 1 con val_acc=0.8295
# Epoch [2/200] Train Loss: 0.8543, Acc: 0.6510 Val Loss: 0.4668, Acc: 0.8511
# ✅ Mejor modelo guardado en epoch 2 con val_acc=0.8511
# Epoch [3/200] Train Loss: 0.7356, Acc: 0.6944 Val Loss: 0.4327, Acc: 0.8437
# Epoch [4/200] Train Loss: 0.7179, Acc: 0.6970 Val Loss: 0.4312, Acc: 0.8262
# Epoch [5/200] Train Loss: 0.6631, Acc: 0.7156 Val Loss: 0.3952, Acc: 0.8456
# Epoch [6/200] Train Loss: 0.6593, Acc: 0.7186 Val Loss: 0.4127, Acc: 0.8430
# Epoch [7/200] Train Loss: 0.6494, Acc: 0.7223 Val Loss: 0.3605, Acc: 0.8640
# ✅ Mejor modelo guardado en epoch 7 con val_acc=0.8640
# Epoch [8/200] Train Loss: 0.6216, Acc: 0.7350 Val Loss: 0.3388, Acc: 0.8764
# ✅ Mejor modelo guardado en epoch 8 con val_acc=0.8764
# Epoch [9/200] Train Loss: 0.6191, Acc: 0.7360 Val Loss: 0.3547, Acc: 0.8831
# ✅ Mejor modelo guardado en epoch 9 con val_acc=0.8831
# Epoch [10/200] Train Loss: 0.5951, Acc: 0.7442 Val Loss: 0.3224, Acc: 0.8702
# Epoch [11/200] Train Loss: 0.5645, Acc: 0.7599 Val Loss: 0.3216, Acc: 0.8883
# ✅ Mejor modelo guardado en epoch 11 con val_acc=0.8883
# Epoch [12/200] Train Loss: 0.5957, Acc: 0.7518 Val Loss: 0.3654, Acc: 0.8674
# Epoch [13/200] Train Loss: 0.5669, Acc: 0.7599 Val Loss: 0.3026, Acc: 0.9001
# ✅ Mejor modelo guardado en epoch 13 con val_acc=0.9001
# Epoch [14/200] Train Loss: 0.5748, Acc: 0.7553 Val Loss: 0.3283, Acc: 0.8766
# Epoch [15/200] Train Loss: 0.5548, Acc: 0.7657 Val Loss: 0.3134, Acc: 0.8855
# Epoch [16/200] Train Loss: 0.5580, Acc: 0.7637 Val Loss: 0.3325, Acc: 0.8613
# Epoch [17/200] Train Loss: 0.5421, Acc: 0.7660 Val Loss: 0.2971, Acc: 0.8905
# Epoch [18/200] Train Loss: 0.5452, Acc: 0.7701 Val Loss: 0.2995, Acc: 0.8993
# Epoch [19/200] Train Loss: 0.5348, Acc: 0.7722 Val Loss: 0.2921, Acc: 0.8695
# Epoch [20/200] Train Loss: 0.5335, Acc: 0.7766 Val Loss: 0.2969, Acc: 0.8742
# Epoch [21/200] Train Loss: 0.5346, Acc: 0.7724 Val Loss: 0.3003, Acc: 0.8917
# Epoch [22/200] Train Loss: 0.5195, Acc: 0.7766 Val Loss: 0.2687, Acc: 0.9022
# ✅ Mejor modelo guardado en epoch 22 con val_acc=0.9022
# Epoch [23/200] Train Loss: 0.5313, Acc: 0.7745 Val Loss: 0.3098, Acc: 0.8914
# Epoch [24/200] Train Loss: 0.5107, Acc: 0.7817 Val Loss: 0.2704, Acc: 0.9093
# ✅ Mejor modelo guardado en epoch 24 con val_acc=0.9093
# Epoch [25/200] Train Loss: 0.5179, Acc: 0.7823 Val Loss: 0.2794, Acc: 0.8957
# Epoch [26/200] Train Loss: 0.5003, Acc: 0.7884 Val Loss: 0.2734, Acc: 0.9182
# ✅ Mejor modelo guardado en epoch 26 con val_acc=0.9182
# Epoch [27/200] Train Loss: 0.5150, Acc: 0.7831 Val Loss: 0.2833, Acc: 0.9025
# Epoch [28/200] Train Loss: 0.5157, Acc: 0.7811 Val Loss: 0.2876, Acc: 0.8978
# Epoch [29/200] Train Loss: 0.5005, Acc: 0.7891 Val Loss: 0.2762, Acc: 0.9028
# Epoch [30/200] Train Loss: 0.4942, Acc: 0.7863 Val Loss: 0.2653, Acc: 0.8880
# Epoch [31/200] Train Loss: 0.4921, Acc: 0.7879 Val Loss: 0.2937, Acc: 0.8748
# Epoch [32/200] Train Loss: 0.5060, Acc: 0.7864 Val Loss: 0.2744, Acc: 0.9007
# Epoch [33/200] Train Loss: 0.4865, Acc: 0.7970 Val Loss: 0.2793, Acc: 0.9110
# Epoch [34/200] Train Loss: 0.4933, Acc: 0.7896 Val Loss: 0.2997, Acc: 0.8935
# Epoch [35/200] Train Loss: 0.4893, Acc: 0.7911 Val Loss: 0.2695, Acc: 0.8951
# Epoch [36/200] Train Loss: 0.4966, Acc: 0.7916 Val Loss: 0.2903, Acc: 0.8793
# Epoch [37/200] Train Loss: 0.4866, Acc: 0.7946 Val Loss: 0.2687, Acc: 0.9065
# Epoch [38/200] Train Loss: 0.4808, Acc: 0.7961 Val Loss: 0.2582, Acc: 0.9187
# ✅ Mejor modelo guardado en epoch 38 con val_acc=0.9187
# Epoch [39/200] Train Loss: 0.4830, Acc: 0.7979 Val Loss: 0.2639, Acc: 0.9203
# ✅ Mejor modelo guardado en epoch 39 con val_acc=0.9203
# Epoch [40/200] Train Loss: 0.4872, Acc: 0.7930 Val Loss: 0.2668, Acc: 0.9074
# Epoch [41/200] Train Loss: 0.4786, Acc: 0.7961 Val Loss: 0.2490, Acc: 0.9117
# Epoch [42/200] Train Loss: 0.4761, Acc: 0.7955 Val Loss: 0.2743, Acc: 0.8917
# Epoch [43/200] Train Loss: 0.4723, Acc: 0.7984 Val Loss: 0.2597, Acc: 0.9025
# Epoch [44/200] Train Loss: 0.4732, Acc: 0.7961 Val Loss: 0.2620, Acc: 0.8951
# Epoch [45/200] Train Loss: 0.4691, Acc: 0.8029 Val Loss: 0.2610, Acc: 0.8730
# Epoch [46/200] Train Loss: 0.4920, Acc: 0.7913 Val Loss: 0.2719, Acc: 0.8815
# Epoch [47/200] Train Loss: 0.4739, Acc: 0.7970 Val Loss: 0.2993, Acc: 0.8763
# Epoch [48/200] Train Loss: 0.4710, Acc: 0.8003 Val Loss: 0.2724, Acc: 0.8945
# Epoch [49/200] Train Loss: 0.4695, Acc: 0.8033 Val Loss: 0.2939, Acc: 0.8723
# Epoch [50/200] Train Loss: 0.4817, Acc: 0.7963 Val Loss: 0.3025, Acc: 0.9015
# Epoch [51/200] Train Loss: 0.4747, Acc: 0.8000 Val Loss: 0.2702, Acc: 0.8862
# Epoch [52/200] Train Loss: 0.4588, Acc: 0.8045 Val Loss: 0.2818, Acc: 0.9012
# Epoch [53/200] Train Loss: 0.4627, Acc: 0.8033 Val Loss: 0.2548, Acc: 0.9043
# Epoch [54/200] Train Loss: 0.4569, Acc: 0.8051 Val Loss: 0.2798, Acc: 0.9095
# ⏹ Early stopping activado
# Entrenamiento finalizado. Mejor val_acc=0.9203, modelo en best_model_fuzzy_current_input.pth

# %%
from sklearn.metrics import cohen_kappa_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

best_model = CNN_FuzzyCurrentInput(num_classes).to(device)
best_model.load_state_dict(torch.load("best_model_fuzzy_current_input.pth", map_location=device))
best_model.eval()

all_labels, all_preds = [], []

with torch.no_grad():
    for x_base, x_cur, y_batch in val_loader:
        x_base, x_cur, y_batch = x_base.to(device), x_cur.to(device), y_batch.to(device)
        outputs = best_model(x_base, x_cur)
        preds = outputs.argmax(dim=1)

        all_labels.extend(y_batch.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())

all_labels = np.array(all_labels)
all_preds = np.array(all_preds)

kappa = cohen_kappa_score(all_labels, all_preds)
print(f"Cohen's Kappa (global): {kappa:.4f}")

cm = confusion_matrix(all_labels, all_preds, labels=np.arange(num_classes))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=unique_labels)

fig, ax = plt.subplots(figsize=(16, 16))
disp.plot(ax=ax, cmap="Blues", colorbar=True, xticks_rotation=90)
plt.title("Matriz de confusión - CNN + Fuzzy Corriente (Entrada)")
plt.show()
# Out:
# Cohen's Kappa (global): 0.9185
